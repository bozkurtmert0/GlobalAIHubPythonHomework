# %% [markdown]
# <a href="https://colab.research.google.com/github/bozkurtmert0/GlobalAIHubPythonHomework/blob/main/Proje.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# class yapisiyla daha duzgun yazilabilirdi

# %%
giris_hakki = 3

durum = True
durum2 = True
dersler = ["Bilgisayar Muhendisligi Giris","Dogrusal Cebir","Veri Yapilari","Derin Ogrenme","Matematik"]
alinan_dersler = {}

midterm = 0
final = 0
project = 0

ders_kodu = 0
#-----------------degerlendirme icin fonksiyon tanimladik-------------------------------------
def degerlendirme (ders , genelnot) :
  if 89 < genelnot:
      not_deger = "AA"
  elif 69 < genelnot < 90:
      not_deger = "BB"
  elif 49 < genelnot < 70:
      not_deger = "CC"
  elif 29 < genelnot < 50:
      not_deger = "DD"
  elif genelnot < 30:
      not_deger = "FF"
      print("Basarisiz")
  alinan_dersler.update({ders : not_deger})
  print(not_deger)
#-------------------------------------------------------------------------------------------

while durum :
  
  ad = "mert"
  soyad = "bozkurt"
  ad.lower()
  soyad.lower()

  in_ad = str(input("Adinizi:"))
  in_soyad = str(input("Soyadinizi:"))
  in_ad.lower()
  in_soyad.lower()

  if ad == in_ad and soyad == in_soyad :
    print("Giris gerceklestirildi")
    print("Hosgeldiniz {} {}".format(ad, soyad))

#-----------------------ders secimi----------------------------------------    
    while durum2 :
      print("*****************************************")
      print("Ders secimi dersin numarasina gore yapiniz")
      print("1 - Bilgisayar Muhendisligi Giris")
      print("2 - Dogrusal Cebir")
      print("3 - Veri Yapilari")
      print("4 - Derin Ogrenme")
      print("5 - Matematik")
      print("Cikis icin q giriniz")
      print("*****************************************")
      print("Secilen dersler")
      print(alinan_dersler)
      print("*****************************************")
      ders_kodu = input()

      if ders_kodu == "1" :
        print("Bilgisayar Muhendisligi Giris dersini aliyorsunuz")
        bmg_midterm = int(input("Midterm notunuzu giriniz :"))
        bmg_final = int(input("Final notunuzu giriniz :"))
        bmg_project = int(input("Project notunuzu giriniz :"))
        bmg_genel = bmg_midterm * 0.3 + bmg_final * 0.5 + bmg_project * 0.2 
        print("Notunuz {}")
        degerlendirme("Bilgisayar Muhendisligi Giris",bmg_genel)
        print("*****************************************")


      elif ders_kodu == "2" :
        print("Dogrusal Cebir dersini aliyorsunuz")
        dc_midterm = int(input("Midterm notunuzu giriniz :"))
        dc_final = int(input("Final notunuzu giriniz :"))
        dc_project = int(input("Project notunuzu giriniz :"))
        dc_genel = dc_midterm * 0.3 + dc_final * 0.5 + dc_project * 0.2 
        print("Notunuz:")
        degerlendirme("Dogrusal Cebir",dc_genel)
        print("*****************************************")
      
      elif ders_kodu == "3" :
        print("Veri Yapilari dersini aliyorsunuz")
        vy_midterm = int(input("Midterm notunuzu giriniz :"))
        vy_final = int(input("Final notunuzu giriniz :"))
        vy_project = int(input("Project notunuzu giriniz :"))
        vy_genel = vy_midterm * 0.3 + vy_final * 0.5 + vy_project * 0.2 
        print("Notunuz:")
        degerlendirme("Veri Yapilari",vy_genel)
        print("*****************************************")
      
      elif ders_kodu == "4" :
        print("Derin Ogrenme Giris dersini aliyorsunuz")
        do_midterm = int(input("Midterm notunuzu giriniz :"))
        do_final = int(input("Final notunuzu giriniz :"))
        do_project = int(input("Project notunuzu giriniz :"))
        do_genel = do_midterm * 0.3 + do_final * 0.5 + do_project * 0.2 
        print("Notunuz:")
        degerlendirme("Derin Ogrenme",do_genel)
        print("*****************************************")

      elif ders_kodu == "5":
        print("Matematik dersini aliyorsunuz")
        mat_midterm = int(input("Midterm notunuzu giriniz :"))
        mat_final = int(input("Final notunuzu giriniz :"))
        mat_project = int(input("Project notunuzu giriniz :"))
        mat_genel = mat_midterm * 0.3 + mat_final * 0.5 + mat_project * 0.2 
        alinan_dersler.append("Matematik")
        print("Notunuz:")
        degerlendirme("Matematik",mat_genel)
        print("*****************************************")

      elif ders_kodu == "Q" or ders_kodu == "q" :
        durum2 = False
        durum = False
            
      else: 
        print("Gecersiz ders kodu girdiniz")
#-------------------ders secimi bitis-----------------------------------------------
    #yetersiz ders seciminde programi durdurcak
    if len(alinan_dersler) < 3 :
      print("Basarisiz oldunuz en az 3 ders almalisiniz")
      durum = False
      
  #fazla basarisiz giris denemsinde programi durdurcak 
  else :
    print("Giris basarisiz lutfen tekrar ")
    giris_hakki -=1
    if giris_hakki == 0 :
      print("Fazla yanlis giris yaptiniz oturum sonlandiriliyor")
      durum = False
# Out:
# Adinizi:mert
# Soyadinizi:bozkurt
# Giris gerceklestirildi
# Hosgeldiniz mert bozkurt
# *****************************************
# Ders secimi dersin numarasina gore yapiniz
# 1 - Bilgisayar Muhendisligi Giris
# 2 - Dogrusal Cebir
# 3 - Veri Yapilari
# 4 - Derin Ogrenme
# 5 - Matematik
# Cikis icin q giriniz
# *****************************************
# Secilen dersler
# {}
# *****************************************
# 1
# Bilgisayar Muhendisligi Giris dersini aliyorsunuz
# Midterm notunuzu giriniz :100
# Final notunuzu giriniz :100
# Project notunuzu giriniz :100
# Notunuz {}
# AA
# *****************************************
# *****************************************
# Ders secimi dersin numarasina gore yapiniz
# 1 - Bilgisayar Muhendisligi Giris
# 2 - Dogrusal Cebir
# 3 - Veri Yapilari
# 4 - Derin Ogrenme
# 5 - Matematik
# Cikis icin q giriniz
# *****************************************
# Secilen dersler
# {'Bilgisayar Muhendisligi Giris': 'AA'}
# ...
